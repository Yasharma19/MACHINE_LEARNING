# %% [markdown]
# SIMPLE LINEAR REGRESSION - It is used to predict values
# It has only one independent variable

# %% [markdown]
# Importing all libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
dataset=pd.read_csv("Salary_Data.csv")
X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %% [markdown]
# Splitting the dataset into train and test datasets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# Training simple linear regression model on training set

# %%
# It has own built-in library in sklearn LinearRegression, so we can import it.
# fit() method of LinearRegresssion class are is to train models in ANN.

from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)   #giving training dataset as an input to fit method
# Out:
# LinearRegression()

# %% [markdown]
# predicting test set results

# %%
#here we only have to give X_test as an input, we have to find the output as predicted values(y_pred) and y_test is actual value
y_pred=regressor.predict(X_test)

# %% [markdown]
# Visualizing training set results

# %%
# Scatter is used ot plot scatter plot
# plot method is used to plot a straight line
plt.scatter(X_train,y_train,color='red')    #it shows the actual data
plt.plot(X_train,regressor.predict(X_train),color='blue')        #here it gives predicted salary of X_train     #plotting regression line
plt.title("SALARY VS EXPERIENCE(TRAINING SET)")
plt.xlabel("YEARS OF EXPERIENCE")
plt.ylabel("SALARY")
plt.show()

# %% [markdown]
# Visualizing test set results

# %%
plt.scatter(X_test,y_test,color='red')    #it shows the actual data
plt.plot(X_test,y_pred,color='blue')        #here it gives predicted salary of X_test     #plotting regression line
plt.title("SALARY VS EXPERIENCE(TESTING SET)")
plt.xlabel("YEARS OF EXPERIENCE")
plt.ylabel("SALARY")
plt.show()
